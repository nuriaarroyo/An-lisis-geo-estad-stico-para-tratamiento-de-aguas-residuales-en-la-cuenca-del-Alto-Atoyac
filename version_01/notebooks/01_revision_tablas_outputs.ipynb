# %% [markdown]
# # Revisión de tablas y outputs del diagnóstico textil Atoyac
#
# Este notebook muestra las tablas generadas por el flujo reproducible. La lectura metodológica es de **priorización preliminar**: identifica actividad textil productiva, confección, maquila, lavado/acabado y proximidad a cauces, sin afirmar contaminación directa.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import display, Markdown, Image, HTML

ROOT = Path.cwd()
if not (ROOT / 'outputs').exists() and (ROOT.parent / 'outputs').exists():
    ROOT = ROOT.parent

TABLES = ROOT / 'outputs' / 'tables'
MAPS = ROOT / 'outputs' / 'maps'
FIGURES = ROOT / 'outputs' / 'figures'
INTERACTIVE = ROOT / 'outputs' / 'maps_interactive'

def read_table(name):
    path = TABLES / name
    if not path.exists():
        display(Markdown(f'**No existe:** `{path}`'))
        return pd.DataFrame()
    return pd.read_csv(path)

def show_table(name, n=20):
    df = read_table(name)
    display(Markdown(f'## `{name}`\nFilas: **{len(df):,}** | Columnas: **{len(df.columns)}**'))
    display(df.head(n))
    return df

pd.set_option('display.max_columns', 80)
pd.set_option('display.max_colwidth', 120)
ROOT
# Out:
# WindowsPath('c:/Users/narro/OneDrive - Fundacion Universidad de las Americas Puebla/servicio social atoyac')

# %% [markdown]
# ## 1. SAIC: lectura municipal y microempresas
#
# SAIC está a nivel municipal/entidad en esta consulta. Sirve para inferir estructura productiva agregada, no para ubicar negocios individuales.

# %%
saic_lectura = show_table('saic_indicadores_lectura_analitica.csv')
# Out:
# ## `saic_indicadores_lectura_analitica.csv`
# Filas: **6** | Columnas: **13**
#         municipio_nombre  actividad_codigo  \
# 0            Huejotzingo               313
# 1            Huejotzingo               314
# 2           Puebla total               313
# 3           Puebla total               315
# 4  San Martín Texmelucan               314
# 5  San Martín Texmelucan               315
#
#                                                actividad_nombre      ue  \
# 0         Fabricación de insumos textiles y acabado de textiles    21.0
# 1  Fabricación de productos textiles, excepto prendas de vestir    22.0
# 2         Fabricación de insumos textiles y acabado de textiles  3137.0
# 3                              Fabricación de prendas de vestir  7040.0
# 4  Fabricación de productos textiles, excepto prendas de vestir    28.0
# 5                              Fabricación de prendas de vestir   321.0
#
#      h001a  personal_promedio  proporcion_familiar  proporcion_remunerado  \
# 0   1233.0          58.714286             0.006488               0.993512
# 1     91.0           4.136364             0.340659               0.637363
# 2  13114.0           4.180427             0.308373               0.687281
# 3  45237.0           6.425710             0.218958               0.773836
# 4     70.0           2.500000             0.542857               0.457143
# 5   1050.0           3.271028             0.473333               0.506667
#
#    ingresos_por_ue  maquila_sobre_ingresos  \
# 0        76.878143                0.038004
# 1         1.092500                0.031413
# 2         3.018933                0.091855
# 3         1.739374                0.442373
# 4         0.476250                0.040945
# 5         0.530150                0.242546
#
#    proxy_unidades_pequenas_familiares  proxy_intensidad_maquila  \
# 0                            0.006488                  0.038004
# 1                            0.340659                  0.031413
# 2                            0.308373                  0.091855
# 3                            0.218958                  0.442373
# 4                            0.542857                  0.040945
# 5                            0.473333                  0.242546
#
#                                                                                                       lectura_metodologica
# 0  Indicadores exploratorios a nivel municipal; no prueban informalidad ni contaminacion. Sirven para comparar estructu...
# 1  Indicadores exploratorios a nivel municipal; no prueban informalidad ni contaminacion. Sirven para comparar estructu...
# 2  Indicadores exploratorios a nivel municipal; no prueban informalidad ni contaminacion. Sirven para comparar estructu...
# 3  Indicadores exploratorios a nivel municipal; no prueban informalidad ni contaminacion. Sirven para comparar estructu...
# 4  Indicadores exploratorios a nivel municipal; no prueban informalidad ni contaminacion. Sirven para comparar estructu...
# 5  Indicadores exploratorios a nivel municipal; no prueban informalidad ni contaminacion. Sirven para comparar estructu...

# %%
micro = show_table('saic_microempresas_estrato_0_10.csv')
# Out:
# ## `saic_microempresas_estrato_0_10.csv`
# Filas: **6** | Columnas: **16**
#         municipio_nombre  actividad_codigo  \
# 0            Huejotzingo               313
# 1            Huejotzingo               314
# 2           Puebla total               313
# 3           Puebla total               315
# 4  San Martín Texmelucan               314
# 5  San Martín Texmelucan               315
#
#                                                actividad_nombre estrato  \
# 0         Fabricación de insumos textiles y acabado de textiles  0 a 10
# 1  Fabricación de productos textiles, excepto prendas de vestir  0 a 10
# 2         Fabricación de insumos textiles y acabado de textiles  0 a 10
# 3                              Fabricación de prendas de vestir  0 a 10
# 4  Fabricación de productos textiles, excepto prendas de vestir  0 a 10
# 5                              Fabricación de prendas de vestir  0 a 10
#
#        ue    h001a   h020a   h010a     m000a    m700a  personal_promedio  \
# 0     5.0     21.0     7.0    14.0     5.013    4.031           4.200000
# 1    19.0     44.0    28.0    14.0     3.353    0.755           2.315789
# 2  2997.0   4105.0  3692.0   404.0   280.753   23.572           1.369703
# 3  6137.0  16030.0  9022.0  6902.0  1828.429  776.440           2.612025
# 4    28.0     70.0    38.0    32.0    13.335    0.546           2.500000
# 5   303.0    753.0   465.0   277.0   111.623   28.990           2.485149
#
#    proporcion_familiar  proporcion_remunerado  ingresos_por_ue  \
# 0             0.333333               0.666667         1.002600
# 1             0.636364               0.318182         0.176474
# 2             0.899391               0.098417         0.093678
# 3             0.562820               0.430568         0.297935
# 4             0.542857               0.457143         0.476250
# 5             0.617530               0.367862         0.368393
#
#    maquila_sobre_ingresos  \
# 0                0.804109
# 1                0.225171
# 2                0.083960
# 3                0.424649
# 4                0.040945
# 5                0.259713
#
#                                                                                                       lectura_metodologica
# 0  Estrato SAIC 0 a 10: evidencia agregada municipal de unidades pequenas. No identifica negocios ni permite ubicarlos ...
# 1  Estrato SAIC 0 a 10: evidencia agregada municipal de unidades pequenas. No identifica negocios ni permite ubicarlos ...
# 2  Estrato SAIC 0 a 10: evidencia agregada municipal de unidades pequenas. No identifica negocios ni permite ubicarlos ...
# 3  Estrato SAIC 0 a 10: evidencia agregada municipal de unidades pequenas. No identifica negocios ni permite ubicarlos ...
# 4  Estrato SAIC 0 a 10: evidencia agregada municipal de unidades pequenas. No identifica negocios ni permite ubicarlos ...
# 5  Estrato SAIC 0 a 10: evidencia agregada municipal de unidades pequenas. No identifica negocios ni permite ubicarlos ...

# %%
if not micro.empty:
    cols = ['municipio_nombre','actividad_codigo','estrato','ue','h001a','personal_promedio','proporcion_familiar','maquila_sobre_ingresos']
    display(micro[cols].sort_values(['municipio_nombre','actividad_codigo']))
# Out:
#         municipio_nombre  actividad_codigo estrato      ue    h001a  \
# 0            Huejotzingo               313  0 a 10     5.0     21.0
# 1            Huejotzingo               314  0 a 10    19.0     44.0
# 2           Puebla total               313  0 a 10  2997.0   4105.0
# 3           Puebla total               315  0 a 10  6137.0  16030.0
# 4  San Martín Texmelucan               314  0 a 10    28.0     70.0
# 5  San Martín Texmelucan               315  0 a 10   303.0    753.0
#
#    personal_promedio  proporcion_familiar  maquila_sobre_ingresos
# 0           4.200000             0.333333                0.804109
# 1           2.315789             0.636364                0.225171
# 2           1.369703             0.899391                0.083960
# 3           2.612025             0.562820                0.424649
# 4           2.500000             0.542857                0.040945
# 5           2.485149             0.617530                0.259713

# %% [markdown]
# ## 2. DENUE textil productivo: clasificación final
#
# La tabla principal de identificación permite rastrear cada punto del mapa por nombre, CLEE, código SCIAN, categoría y distancia al cauce. El análisis excluye comercio de prendas y conserva producción/confección/maquila/lavado/acabado.

# %%
resumen_denue = show_table('resumen_denue_por_localidad_categoria.csv')
# Out:
# ## `resumen_denue_por_localidad_categoria.csv`
# Filas: **9** | Columnas: **3**
#    localidad_o_fuente categoria_relevancia_ambiental  establecimientos
# 0   agebs\huejotzingo      alta_relevancia_ambiental                44
# 1   agebs\huejotzingo     media_relevancia_ambiental                32
# 2   agebs\huejotzingo                        revisar                29
# 3    agebs\san_martin      alta_relevancia_ambiental               119
# 4    agebs\san_martin     media_relevancia_ambiental               390
# 5    agebs\san_martin                        revisar               101
# 6  agebs\xalmimilulco      alta_relevancia_ambiental                23
# 7  agebs\xalmimilulco     media_relevancia_ambiental               277
# 8  agebs\xalmimilulco                        revisar                52

# %%
identificacion = show_table('denue_textil_identificacion.csv', n=25)
# Out:
# ## `denue_textil_identificacion.csv`
# Filas: **1,067** | Columnas: **12**
#           id                          clee  \
# 0    3325807  21074315229001032000000000U7
# 1    3325813  21074313210000056111000000U9
# 2    3325963  21074315225000111000000000U8
# 3    7872777  21074315229001612000000000U6
# 4    8089412  21074315229001873000000000U4
# 5    8089749  21074315229001921000000000U1
# 6    8111993  21074315225000161001000000U3
# 7    8121067  21074315225000191000000000U0
# 8    8271641  21074465915000021010000000U3
# 9    8271825  21074812210000401000000000U3
# 10   8279928  21074812210000541000000000U6
# 11   8592165  21074812210000571000000000U3
# 12   8803988  21074812210000561000000000U4
# 13   9347738  21074315229002223001000000U1
# 14   9440789  21074325620000013000000000U6
# 15   9624559  21074812210000681000000000U0
# 16   9682319  21074314991000271000000000U8
# 17   9734956  21074315229002843000000000U6
# 18  10070109  21074812210000981000000000U4
# 19  10118182  21074812210000811000000000U3
# 20  10183338  21074315225000241000000000U3
# 21  10205167  21074313210000083000000000U3
# 22  10279073  21074812210000841000000000U0
# 23  10340864  21074812210000731000000000U3
# 24  10414011  21074315224000071000000000U7
#
#                         nombre_de_la_unidad_economica  \
# 0               TEXTILERA DE PANTALON JEANS EMOCIONES
# 1                                   INDUSTRIAS MAQUIN
# 2                                 SONIA MENDEZ NOVIAS
# 3                                 TALLER BOMBON JEANS
# 4                       TALLER DE PANTALON SIN NOMBRE
# 5                   DESHEBRADO DE PANTALON SIN NOMBRE
# 6                      ELABORACION DE ROPA SIN NOMBRE
# 7                                       MODISTA LUCIA
# 8                                    CREACIONES MAYRA
# 9                                TINTORERIA HIGIENICA
# 10                             LAVANDERIA EL REHILETE
# 11                             LAVANDERIA SUNNY CLEAN
# 12                                TINTORERIA SANTIAGO
# 13              MAQUILADORA ESTYR BLUE MICHELLE JEANS
# 14                 PMP PRODUCTOS Y MAQUILAS DE PUEBLA
# 15                                  LAVANDERIA SERGIO
# 16                            BORDADOS COMPUTARIZADOS
# 17                                COLMEX CONFECCIONES
# 18                               LAVANDERIA JUQUILITA
# 19                                      CLEAN CLOTHES
# 20  TALLER DE COSTURA Y VENTA DE HUARACHES SIN NOMBRE
# 21                         BODEGA PUNTO FINO EN TELAS
# 22                              LAVANDERIA SIN NOMBRE
# 23                                          TINTOWASH
# 24                ELABORACION DE MASCARAS ARTESANALES
#
#     codigo_de_la_clase_actividad_scian      source_folder  \
# 0                               315229  agebs\huejotzingo
# 1                               313230  agebs\huejotzingo
# 2                               315225  agebs\huejotzingo
# 3                               315229  agebs\huejotzingo
# 4                               315229  agebs\huejotzingo
# 5                               315229  agebs\huejotzingo
# 6                               315225  agebs\huejotzingo
# 7                               315225  agebs\huejotzingo
# 8                               315224  agebs\huejotzingo
# 9                               812210  agebs\huejotzingo
# 10                              812210  agebs\huejotzingo
# 11                              812210  agebs\huejotzingo
# 12                              812210  agebs\huejotzingo
# 13                              315229  agebs\huejotzingo
# 14                              325620  agebs\huejotzingo
# 15                              812210  agebs\huejotzingo
# 16                              314991  agebs\huejotzingo
# 17                              315229  agebs\huejotzingo
# 18                              812210  agebs\huejotzingo
# 19                              812210  agebs\huejotzingo
# 20                              315225  agebs\huejotzingo
# 21                              313210  agebs\huejotzingo
# 22                              812210  agebs\huejotzingo
# 23                              812210  agebs\huejotzingo
# 24                              315224  agebs\huejotzingo
#
#    categoria_relevancia_ambiental palabras_clave_detectadas  \
# 0      media_relevancia_ambiental   jeans; pantalon; textil
# 1                         revisar                       NaN
# 2                         revisar                       NaN
# 3      media_relevancia_ambiental                     jeans
# 4      media_relevancia_ambiental                  pantalon
# 5      media_relevancia_ambiental      deshebrado; pantalon
# 6      media_relevancia_ambiental                       NaN
# 7      media_relevancia_ambiental                   modista
# 8                         revisar                       NaN
# 9       alta_relevancia_ambiental                tintoreria
# 10      alta_relevancia_ambiental                lavanderia
# 11      alta_relevancia_ambiental                lavanderia
# 12      alta_relevancia_ambiental                tintoreria
# 13     media_relevancia_ambiental            jeans; maquila
# 14     media_relevancia_ambiental                   maquila
# 15      alta_relevancia_ambiental                lavanderia
# 16     media_relevancia_ambiental                   bordado
# 17     media_relevancia_ambiental                confeccion
# 18      alta_relevancia_ambiental                lavanderia
# 19                        revisar                       NaN
# 20     media_relevancia_ambiental                   costura
# 21                        revisar                       NaN
# 22      alta_relevancia_ambiental                lavanderia
# 23                        revisar                       NaN
# 24     media_relevancia_ambiental                       NaN
#
#     distancia_hidrografia_m rango_distancia_hidrografia    latitud   longitud  \
# 0                563.161289                  500-1000 m  19.164383 -98.420451
# 1                921.240971                  500-1000 m  19.161344 -98.391562
# 2               1041.667327                     >1000 m  19.163965 -98.404081
# 3                240.644089                   100-250 m  19.161026 -98.401670
# 4               1217.059569                     >1000 m  19.161100 -98.403837
# 5                336.258144                   250-500 m  19.170984 -98.407411
# 6                 85.986463                     0-100 m  19.171194 -98.409099
# 7                374.404701                   250-500 m  19.147233 -98.406032
# 8                363.020287                   250-500 m  19.165291 -98.406506
# 9                550.754352                  500-1000 m  19.161175 -98.411337
# 10               658.466882                  500-1000 m  19.160775 -98.400404
# 11               184.002792                   100-250 m  19.154724 -98.408652
# 12               153.347869                   100-250 m  19.154858 -98.408564
# 13                22.249693                     0-100 m  19.155365 -98.400280
# 14                42.909236                     0-100 m  19.166259 -98.386093
# 15                 7.814714                     0-100 m  19.176968 -98.391069
# 16               220.374012                   100-250 m  19.161593 -98.412139
# 17               720.280272                  500-1000 m  19.152353 -98.407237
# 18                46.680596                     0-100 m  19.164646 -98.411764
# 19               604.944739                  500-1000 m  19.148389 -98.405906
# 20               127.279816                   100-250 m  19.160375 -98.409697
# 21              1062.523188                     >1000 m  19.162693 -98.386820
# 22               341.440584                   250-500 m  19.177482 -98.390068
# 23              1184.036585                     >1000 m  19.161238 -98.408648
# 24               364.026112                   250-500 m  19.162034 -98.399862
#
#                                                                                                           nota_metodologica
# 0   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 1   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 2   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 3   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 4   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 5   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 6   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 7   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 8   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 9   Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 10  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 11  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 12  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 13  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 14  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 15  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 16  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 17  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 18  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 19  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 20  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 21  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 22  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 23  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...
# 24  Priorizacion preliminar por produccion, confeccion, maquila, acabado o lavado textil; se excluye comercio de prendas...

# %%
if not identificacion.empty:
    display(Markdown('### Conteo por región y categoría'))
    pivot = identificacion.pivot_table(index='source_folder', columns='categoria_relevancia_ambiental', values='id', aggfunc='count', fill_value=0)
    pivot['total'] = pivot.sum(axis=1)
    display(pivot)
# Out:
# ### Conteo por región y categoría
# categoria_relevancia_ambiental  alta_relevancia_ambiental  \
# source_folder
# agebs\huejotzingo                                      44
# agebs\san_martin                                      119
# agebs\xalmimilulco                                     23
#
# categoria_relevancia_ambiental  media_relevancia_ambiental  revisar  total
# source_folder
# agebs\huejotzingo                                       32       29    105
# agebs\san_martin                                       390      101    610
# agebs\xalmimilulco                                     277       52    352

# %% [markdown]
# ## 3. Auditoría: registros excluidos por comercio o falsos positivos
#
# Esta tabla ayuda a revisar qué se quitó del análisis productivo para no mezclar boutiques, tiendas, comercio de ropa o talleres no textiles.

# %%
excluidos = show_table('denue_excluidos_comercio_prendas.csv', n=30)
# Out:
# ## `denue_excluidos_comercio_prendas.csv`
# Filas: **147** | Columnas: **12**
#           id                          clee  \
# 0    3326398  21074811192000231000000000U5
# 1    3418468  21074811192000021000000000U9
# 2    3418518  21074811192000141000000000U6
# 3    3418604  21074811192000191000000000U1
# 4    3426682  21074463211000621000000000U6
# 5    3426890  21074315223000021000000000U4
# 6    8089578  21074314991000191000000000U8
# 7    8120601  21074315223000041000000000U2
# 8    8121071  21074811192000431000000000U1
# 9    8271458  21074811192000371000000000U9
# 10   8672381  21074811192000441000000000U0
# 11   8940288  21074811192000341000000000U2
# 12  10248328  21074811192000571000000000U4
# 13  10760160  21074811192000621000000000U7
# 14  10788794  21074315225000221000000000U5
# 15  10888207  21074811192000581000000000U3
# 16  11108254  21074463112000061000000000U5
# 17   3325938  21074811192000271000000000U1
# 18   3326626  21074811192000311000000000U5
# 19   3326640  21074811192000211000000000U7
# 20   3326936  21074811192000221000000000U6
# 21   3427083  21074463211000711000000000U5
# 22   6855246  21074462112000292001008202S7
# 23   8088976  21074315224000031000000000U1
# 24   8088978  21074315225000171000000000U2
# 25   8089458  21074811192000411000000000U3
# 26   8089527  21074811192000421000000000U2
# 27   8858047  21074811192000331000000000U3
# 28   9520733  21074811192000511000000000U0
# 29   9532624  21074811192000501000000000U1
#
#                      nombre_de_la_unidad_economica  \
# 0                               AUTOLAVADO MONTANA
# 1                            AUTOLAVADO SAN MIGUEL
# 2                          AUTO LAVADO EL TIO MIGO
# 3                                 AUTOLAVADO IBIZA
# 4                              PP S JEANS BOUTIQUE
# 5                TIENDA DE ROPA UNIFORMES MENDIETA
# 6                        VENTA DE GAZNE SIN NOMBRE
# 7               VENTA DE UNIFORMES ESCOLARES GORZO
# 8                               AUTOLAVADO EL CHAS
# 9                         AUTO LAVADO CLICK MASTER
# 10                   AUTO LAVADO CON ESPUMA ACTIVA
# 11                           AUTOLAVADO SIN NOMBRE
# 12                            AUTO LAVADO AUTO SPA
# 13                           AUTOLAVADO SIN NOMBRE
# 14                                  BOUTIQUE ADORA
# 15                               AUTOLAVADO SEYNOS
# 16                                  MAFER TEXTILES
# 17                 AUTOLAVADO A PRESION SIN NOMBRE
# 18                           AUTOLAVADO SIN NOMBRE
# 19                          AUTO LAVADO SIN NOMBRE
# 20                              AUTO LAVADO LUPITA
# 21                           CONFECCIONES TEYSSIER
# 22                OXXO SUC 50E4Y CIUDAD TEXTIL PBF
# 23  VENTA Y RENTA DE TRAJES DE CARNAVAL SIN NOMBRE
# 24                  VENTA DE VESTIDOS DE NIÑO DIOS
# 25                        LAVADO DE AUTOS CAR WASH
# 26                              AUTOLAVADO AGUILAR
# 27                           AUTOLAVADO SIN NOMBRE
# 28                           AUTO LAVADO SINNOMBRE
# 29                        AUTO LAVADO CLICK MASTER
#
#     codigo_de_la_clase_actividad_scian    latitud   longitud  \
# 0                               811192  19.169467 -98.406828
# 1                               811192  19.159396 -98.414989
# 2                               811192  19.158651 -98.414156
# 3                               811192  19.149259 -98.404001
# 4                               463211  19.161949 -98.406915
# 5                               315223  19.160859 -98.411380
# 6                               314991  19.161690 -98.408592
# 7                               315223  19.158322 -98.409853
# 8                               811192  19.148074 -98.405935
# 9                               811192  19.158323 -98.412537
# 10                              811192  19.161623 -98.404280
# 11                              811192  19.169147 -98.405169
# 12                              811192  19.149970 -98.409603
# 13                              811192  19.160337 -98.412290
# 14                              315225  19.168438 -98.405352
# 15                              811192  19.163151 -98.418607
# 16                              463112  19.161132 -98.406126
# 17                              811192  19.168268 -98.405200
# 18                              811192  19.154664 -98.406884
# 19                              811192  19.153645 -98.402530
# 20                              811192  19.149232 -98.401881
# 21                              463211  19.159726 -98.404510
# 22                              462112  19.157518 -98.379735
# 23                              315224  19.164510 -98.408886
# 24                              315229  19.164076 -98.408370
# 25                              811192  19.161154 -98.404339
# 26                              811192  19.161683 -98.406045
# 27                              811192  19.172795 -98.404672
# 28                              811192  19.151094 -98.413357
# 29                              811192  19.155796 -98.406437
#
#                                     source_path       source_file  \
# 0   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 1   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 2   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 3   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 4   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 5   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 6   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 7   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 8   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 9   data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 10  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 11  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 12  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 13  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 14  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 15  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 16  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 17  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 18  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 19  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 20  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 21  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 22  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 23  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 24  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 25  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 26  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 27  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 28  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
# 29  data\raw\agebs\huejotzingo\INEGI_DENUE_.shp  INEGI_DENUE_.shp
#
#         source_folder layer_type  \
# 0   agebs\huejotzingo      denue
# 1   agebs\huejotzingo      denue
# 2   agebs\huejotzingo      denue
# 3   agebs\huejotzingo      denue
# 4   agebs\huejotzingo      denue
# 5   agebs\huejotzingo      denue
# 6   agebs\huejotzingo      denue
# 7   agebs\huejotzingo      denue
# 8   agebs\huejotzingo      denue
# 9   agebs\huejotzingo      denue
# 10  agebs\huejotzingo      denue
# 11  agebs\huejotzingo      denue
# 12  agebs\huejotzingo      denue
# 13  agebs\huejotzingo      denue
# 14  agebs\huejotzingo      denue
# 15  agebs\huejotzingo      denue
# 16  agebs\huejotzingo      denue
# 17  agebs\huejotzingo      denue
# 18  agebs\huejotzingo      denue
# 19  agebs\huejotzingo      denue
# 20  agebs\huejotzingo      denue
# 21  agebs\huejotzingo      denue
# 22  agebs\huejotzingo      denue
# 23  agebs\huejotzingo      denue
# 24  agebs\huejotzingo      denue
# 25  agebs\huejotzingo      denue
# 26  agebs\huejotzingo      denue
# 27  agebs\huejotzingo      denue
# 28  agebs\huejotzingo      denue
# 29  agebs\huejotzingo      denue
#
#                                                                                                              texto_busqueda  \
# 0   21074811192000231000000000u5 autolavado montana 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp ...
# 1   21074811192000021000000000u9 autolavado san miguel 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.s...
# 2   21074811192000141000000000u6 auto lavado el tio migo 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_...
# 3   21074811192000191000000000u1 autolavado ibiza 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp ag...
# 4   21074463211000621000000000u6 pp s jeans boutique 463211 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp...
# 5   21074315223000021000000000u4 tienda de ropa uniformes mendieta 315223 data\raw\agebs\huejotzingo\inegi_denue_.shp in...
# 6   21074314991000191000000000u8 venta de gazne sin nombre 314991 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denu...
# 7   21074315223000041000000000u2 venta de uniformes escolares gorzo 315223 data\raw\agebs\huejotzingo\inegi_denue_.shp i...
# 8   21074811192000431000000000u1 autolavado el chas 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp ...
# 9   21074811192000371000000000u9 auto lavado click master 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue...
# 10  21074811192000441000000000u0 auto lavado con espuma activa 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_...
# 11  21074811192000341000000000u2 autolavado sin nombre 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.s...
# 12  21074811192000571000000000u4 auto lavado auto spa 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.sh...
# 13  21074811192000621000000000u7 autolavado sin nombre 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.s...
# 14  21074315225000221000000000u5 boutique adora 315225 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp ageb...
# 15  21074811192000581000000000u3 autolavado seynos 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp a...
# 16  21074463112000061000000000u5 mafer textiles 463112 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp ageb...
# 17  21074811192000271000000000u1 autolavado a presion sin nombre 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp ineg...
# 18  21074811192000311000000000u5 autolavado sin nombre 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.s...
# 19  21074811192000211000000000u7 auto lavado sin nombre 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_....
# 20  21074811192000221000000000u6 auto lavado lupita 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp ...
# 21  21074463211000711000000000u5 confecciones teyssier 463211 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.s...
# 22  21074462112000292001008202s7 oxxo suc 50e4y ciudad textil pbf 462112 data\raw\agebs\huejotzingo\inegi_denue_.shp ine...
# 23  21074315224000031000000000u1 venta y renta de trajes de carnaval sin nombre 315224 data\raw\agebs\huejotzingo\inegi_...
# 24  21074315225000171000000000u2 venta de vestidos de nino dios 315229 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi...
# 25  21074811192000411000000000u3 lavado de autos car wash 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue...
# 26  21074811192000421000000000u2 autolavado aguilar 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.shp ...
# 27  21074811192000331000000000u3 autolavado sin nombre 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.s...
# 28  21074811192000511000000000u0 auto lavado sinnombre 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue_.s...
# 29  21074811192000501000000000u1 auto lavado click master 811192 data\raw\agebs\huejotzingo\inegi_denue_.shp inegi_denue...
#
#     codigo_scian_detectado
# 0                   811192
# 1                   811192
# 2                   811192
# 3                   811192
# 4                   463211
# 5                   315223
# 6                   314991
# 7                   315223
# 8                   811192
# 9                   811192
# 10                  811192
# 11                  811192
# 12                  811192
# 13                  811192
# 14                  315225
# 15                  811192
# 16                  463112
# 17                  811192
# 18                  811192
# 19                  811192
# 20                  811192
# 21                  463211
# 22                  462112
# 23                  315224
# 24                  315229
# 25                  811192
# 26                  811192
# 27                  811192
# 28                  811192
# 29                  811192

# %% [markdown]
# ## 4. Proximidad a cauces e hidrografía
#
# Los rangos son bandas de proximidad/cautela: no son intervalos estadísticos de confianza ni evidencian contaminación directa.

# %%
rangos = show_table('conteo_negocios_por_rango_distancia.csv', n=50)
# Out:
# ## `conteo_negocios_por_rango_distancia.csv`
# Filas: **44** | Columnas: **4**
#          source_folder rango_distancia_hidrografia  \
# 0    agebs\huejotzingo                     0-100 m
# 1    agebs\huejotzingo                     0-100 m
# 2    agebs\huejotzingo                     0-100 m
# 3    agebs\huejotzingo                   100-250 m
# 4    agebs\huejotzingo                   100-250 m
# 5    agebs\huejotzingo                   100-250 m
# 6    agebs\huejotzingo                   250-500 m
# 7    agebs\huejotzingo                   250-500 m
# 8    agebs\huejotzingo                   250-500 m
# 9    agebs\huejotzingo                  500-1000 m
# 10   agebs\huejotzingo                  500-1000 m
# 11   agebs\huejotzingo                  500-1000 m
# 12   agebs\huejotzingo                     >1000 m
# 13   agebs\huejotzingo                     >1000 m
# 14   agebs\huejotzingo                     >1000 m
# 15    agebs\san_martin                     0-100 m
# 16    agebs\san_martin                     0-100 m
# 17    agebs\san_martin                     0-100 m
# 18    agebs\san_martin                   100-250 m
# 19    agebs\san_martin                   100-250 m
# 20    agebs\san_martin                   100-250 m
# 21    agebs\san_martin                   250-500 m
# 22    agebs\san_martin                   250-500 m
# 23    agebs\san_martin                   250-500 m
# 24    agebs\san_martin                  500-1000 m
# 25    agebs\san_martin                  500-1000 m
# 26    agebs\san_martin                  500-1000 m
# 27    agebs\san_martin                     >1000 m
# 28    agebs\san_martin                     >1000 m
# 29    agebs\san_martin                     >1000 m
# 30  agebs\xalmimilulco                     0-100 m
# 31  agebs\xalmimilulco                     0-100 m
# 32  agebs\xalmimilulco                   100-250 m
# 33  agebs\xalmimilulco                   100-250 m
# 34  agebs\xalmimilulco                   100-250 m
# 35  agebs\xalmimilulco                   250-500 m
# 36  agebs\xalmimilulco                   250-500 m
# 37  agebs\xalmimilulco                   250-500 m
# 38  agebs\xalmimilulco                  500-1000 m
# 39  agebs\xalmimilulco                  500-1000 m
# 40  agebs\xalmimilulco                  500-1000 m
# 41  agebs\xalmimilulco                     >1000 m
# 42  agebs\xalmimilulco                     >1000 m
# 43  agebs\xalmimilulco                     >1000 m
#
#    categoria_relevancia_ambiental  establecimientos
# 0       alta_relevancia_ambiental                11
# 1      media_relevancia_ambiental                 5
# 2                         revisar                 2
# 3       alta_relevancia_ambiental                11
# 4      media_relevancia_ambiental                10
# 5                         revisar                 7
# 6       alta_relevancia_ambiental                 8
# 7      media_relevancia_ambiental                 7
# 8                         revisar                 7
# 9       alta_relevancia_ambiental                13
# 10     media_relevancia_ambiental                 7
# 11                        revisar                 7
# 12      alta_relevancia_ambiental                 1
# 13     media_relevancia_ambiental                 3
# 14                        revisar                 6
# 15      alta_relevancia_ambiental                12
# 16     media_relevancia_ambiental                47
# 17                        revisar                 9
# 18      alta_relevancia_ambiental                26
# 19     media_relevancia_ambiental                71
# 20                        revisar                19
# 21      alta_relevancia_ambiental                51
# 22     media_relevancia_ambiental               136
# 23                        revisar                43
# 24      alta_relevancia_ambiental                29
# 25     media_relevancia_ambiental               121
# 26                        revisar                29
# 27      alta_relevancia_ambiental                 1
# 28     media_relevancia_ambiental                15
# 29                        revisar                 1
# 30     media_relevancia_ambiental                15
# 31                        revisar                 2
# 32      alta_relevancia_ambiental                 1
# 33     media_relevancia_ambiental                18
# 34                        revisar                 2
# 35      alta_relevancia_ambiental                 3
# 36     media_relevancia_ambiental                40
# 37                        revisar                 7
# 38      alta_relevancia_ambiental                12
# 39     media_relevancia_ambiental               150
# 40                        revisar                32
# 41      alta_relevancia_ambiental                 7
# 42     media_relevancia_ambiental                54
# 43                        revisar                 9

# %%
buffers = show_table('conteo_negocios_por_buffer.csv')
# Out:
# ## `conteo_negocios_por_buffer.csv`
# Filas: **12** | Columnas: **3**
#     buffer_m categoria_relevancia_ambiental  establecimientos
# 0        100      alta_relevancia_ambiental                23
# 1        100     media_relevancia_ambiental                67
# 2        100                        revisar                13
# 3        250      alta_relevancia_ambiental                61
# 4        250     media_relevancia_ambiental               166
# 5        250                        revisar                41
# 6        500      alta_relevancia_ambiental               123
# 7        500     media_relevancia_ambiental               349
# 8        500                        revisar                98
# 9       1000      alta_relevancia_ambiental               177
# 10      1000     media_relevancia_ambiental               627
# 11      1000                        revisar               166

# %% [markdown]
# ## 5. Inventario y control de calidad

# %%
inventario = show_table('inventario_capas.csv', n=15)
errores = show_table('errores_inventario_capas.csv', n=15)
# Out:
# ## `inventario_capas.csv`
# Filas: **106** | Columnas: **11**
#                                                               ruta  \
# 0                       data\raw\agebs\huejotzingo\INEGI_AGEB_.shp
# 1   data\raw\agebs\huejotzingo\INEGI_Arearuralesnoamanzanadas_.shp
# 2                    data\raw\agebs\huejotzingo\INEGI_Caminos_.shp
# 3                 data\raw\agebs\huejotzingo\INEGI_Carreteras_.shp
# 4                    data\raw\agebs\huejotzingo\INEGI_Cuencas_.shp
# 5                      data\raw\agebs\huejotzingo\INEGI_DENUE_.shp
# 6                    data\raw\agebs\huejotzingo\INEGI_Estatal_.shp
# 7                  data\raw\agebs\huejotzingo\INEGI_Localidad_.shp
# 8                   data\raw\agebs\huejotzingo\INEGI_Manzanas_.shp
# 9                   data\raw\agebs\huejotzingo\INEGI_Regiones_.shp
# 10                data\raw\agebs\huejotzingo\INEGI_Subcuencas_.shp
# 11                data\raw\agebs\huejotzingo\INEGI_Vialidades_.shp
# 12                       data\raw\agebs\san_martin\INEGI_AGEB_.shp
# 13   data\raw\agebs\san_martin\INEGI_Arearuralesnoamanzanadas_.shp
# 14                    data\raw\agebs\san_martin\INEGI_Caminos_.shp
#
#                          nombre_archivo     carpeta_origen  numero_features  \
# 0                       INEGI_AGEB_.shp  agebs\huejotzingo             41.0
# 1   INEGI_Arearuralesnoamanzanadas_.shp  agebs\huejotzingo             32.0
# 2                    INEGI_Caminos_.shp  agebs\huejotzingo             51.0
# 3                 INEGI_Carreteras_.shp  agebs\huejotzingo            236.0
# 4                    INEGI_Cuencas_.shp  agebs\huejotzingo              1.0
# 5                      INEGI_DENUE_.shp  agebs\huejotzingo           4051.0
# 6                    INEGI_Estatal_.shp  agebs\huejotzingo              1.0
# 7                  INEGI_Localidad_.shp  agebs\huejotzingo             23.0
# 8                   INEGI_Manzanas_.shp  agebs\huejotzingo            796.0
# 9                   INEGI_Regiones_.shp  agebs\huejotzingo              1.0
# 10                INEGI_Subcuencas_.shp  agebs\huejotzingo              1.0
# 11                INEGI_Vialidades_.shp  agebs\huejotzingo           2815.0
# 12                      INEGI_AGEB_.shp   agebs\san_martin             80.0
# 13  INEGI_Arearuralesnoamanzanadas_.shp   agebs\san_martin             34.0
# 14                   INEGI_Caminos_.shp   agebs\san_martin            121.0
#
#      geometria  \
# 0      Polygon
# 1        Point
# 2   LineString
# 3   LineString
# 4      Polygon
# 5        Point
# 6      Polygon
# 7      Polygon
# 8      Polygon
# 9      Polygon
# 10     Polygon
# 11  LineString
# 12     Polygon
# 13       Point
# 14  LineString
#
#                                                                                                                         crs  \
# 0   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 1   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 2   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 3   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 4   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 5   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 6   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 7   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 8   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 9   GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 10  GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 11  GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 12  GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 13  GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
# 14  GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174...
#
#                                                                                                        columnas_disponibles  \
# 0                                                                                                                ID; CVEGEO
# 1                                                                                         CVE_ENT; CVE_MUN; CVE_LOC; NOMBRE
# 2   OGR_FID; ID_RED; TIPO_VIAL; NOMBRE; CODIGO; COND_PAV; RECUBRI; CARRILES; ESTATUS; CONDICION; NIVEL; PEAJE; ADMINISTR...
# 3   OGR_FID; ID_RED; TIPO_VIAL; NOMBRE; CODIGO; COND_PAV; RECUBRI; CARRILES; ESTATUS; CONDICION; NIVEL; PEAJE; ADMINISTR...
# 4                                                                        CVECUENCA; CVE_RH; RH; CUENCA; AREA_KM2; PERIMETRO
# 5                                              id_llave_r; subsector_; rama_activ; subrama_ac; clase_acti; estrato_pe; x; y
# 6                                                                                                                ID; NOMBRE
# 7                                                                                                                ID; NOMBRE
# 8   CVEGEO; CVE_ENT; NOM_ENT; CVE_MUN; NOM_MUN; CVE_LOC; NOM_LOC; CVE_AGEB; CVE_MZA; POBTOT; POBFEM; POBMAS; POB0_14; PO...
# 9                                                                                 IDDB; ID; CVE_RH; RH; AREA_KM2; PERIMETRO
# 10                                ID; CVE_SUBCUE; CVE_RH; RH; CVECUENCA; CUENCA; SUBCUENCA; AREA_KM2; PERIMETRO; Cuenca_hid
# 11                                                                          CVEGEO; TIPO_VIAL; NOM_VIAL; SENTIDO; FECHA_ACT
# 12                                                                                                               ID; CVEGEO
# 13                                                                                        CVE_ENT; CVE_MUN; CVE_LOC; NOMBRE
# 14  OGR_FID; ID_RED; TIPO_VIAL; NOMBRE; CODIGO; COND_PAV; RECUBRI; CARRILES; ESTATUS; CONDICION; NIVEL; PEAJE; ADMINISTR...
#
#                                                                                                              tipos_columnas  \
# 0                                                                                                  ID:object; CVEGEO:object
# 1                                                             CVE_ENT:object; CVE_MUN:object; CVE_LOC:object; NOMBRE:object
# 2   OGR_FID:int32; ID_RED:int64; TIPO_VIAL:object; NOMBRE:object; CODIGO:object; COND_PAV:object; RECUBRI:object; CARRIL...
# 3   OGR_FID:int32; ID_RED:int64; TIPO_VIAL:object; NOMBRE:object; CODIGO:object; COND_PAV:object; RECUBRI:object; CARRIL...
# 4                                CVECUENCA:object; CVE_RH:object; RH:object; CUENCA:object; AREA_KM2:int32; PERIMETRO:int32
# 5   id_llave_r:int32; subsector_:object; rama_activ:object; subrama_ac:object; clase_acti:object; estrato_pe:object; x:f...
# 6                                                                                                  ID:object; NOMBRE:object
# 7                                                                                                  ID:object; NOMBRE:object
# 8   CVEGEO:object; CVE_ENT:object; NOM_ENT:object; CVE_MUN:object; NOM_MUN:object; CVE_LOC:object; NOM_LOC:object; CVE_A...
# 9                                           IDDB:int32; ID:int32; CVE_RH:object; RH:object; AREA_KM2:int32; PERIMETRO:int32
# 10  ID:int32; CVE_SUBCUE:object; CVE_RH:object; RH:object; CVECUENCA:object; CUENCA:object; SUBCUENCA:object; AREA_KM2:i...
# 11                                       CVEGEO:object; TIPO_VIAL:object; NOM_VIAL:object; SENTIDO:object; FECHA_ACT:object
# 12                                                                                                 ID:object; CVEGEO:object
# 13                                                            CVE_ENT:object; CVE_MUN:object; CVE_LOC:object; NOMBRE:object
# 14  OGR_FID:int32; ID_RED:int64; TIPO_VIAL:object; NOMBRE:object; CODIGO:object; COND_PAV:object; RECUBRI:object; CARRIL...
#
#                                                                                            bounds_extension_espacial  \
# 0    {"minx": -98.46796629436409, "miny": 19.133349003923783, "maxx": -98.3484397001108, "maxy": 19.180490866928135}
# 1    {"minx": -98.45916331174493, "miny": 19.133602134499863, "maxx": -98.35095083853747, "maxy": 19.17916379065656}
# 2      {"minx": -98.46796629436407, "miny": 19.133350887826, "maxx": -98.34843970011083, "maxy": 19.180490586158978}
# 3     {"minx": -98.46796629436407, "miny": 19.13335319458822, "maxx": -98.34854975199994, "maxy": 19.18049120620316}
# 4   {"minx": -98.46796629436405, "miny": 19.133349003923783, "maxx": -98.34843970011086, "maxy": 19.180481584436848}
# 5                             {"minx": -98.46657637, "miny": 19.13469408, "maxx": -98.34845044, "maxy": 19.18032349}
# 6   {"minx": -98.46796629436405, "miny": 19.133349003923783, "maxx": -98.34843970011086, "maxy": 19.180481584436848}
# 7     {"minx": -98.46796629436409, "miny": 19.133352082056646, "maxx": -98.3484397001108, "maxy": 19.18049125624377}
# 8     {"minx": -98.46796629436409, "miny": 19.133352286801667, "maxx": -98.3484397001108, "maxy": 19.18048933016645}
# 9   {"minx": -98.46796629436405, "miny": 19.133349003923783, "maxx": -98.34843970011086, "maxy": 19.180481584436848}
# 10  {"minx": -98.46796629436405, "miny": 19.133349003923783, "maxx": -98.34843970011086, "maxy": 19.180481584436848}
# 11   {"minx": -98.46796629436409, "miny": 19.133352082056646, "maxx": -98.3484397001108, "maxy": 19.180491124363577}
# 12   {"minx": -98.50957962463013, "miny": 19.26295013705918, "maxx": -98.38015700845718, "maxy": 19.313954350657305}
# 13     {"minx": -98.49261330316676, "miny": 19.2659148816888, "maxx": -98.3839536078838, "maxy": 19.313287926477877}
# 14   {"minx": -98.5095796246301, "miny": 19.262960847480013, "maxx": -98.38015700845718, "maxy": 19.313955376200173}
#
#                    estado  \
# 0   ok_geopandas_fallback
# 1   ok_geopandas_fallback
# 2   ok_geopandas_fallback
# 3   ok_geopandas_fallback
# 4   ok_geopandas_fallback
# 5   ok_geopandas_fallback
# 6   ok_geopandas_fallback
# 7   ok_geopandas_fallback
# 8   ok_geopandas_fallback
# 9   ok_geopandas_fallback
# 10  ok_geopandas_fallback
# 11  ok_geopandas_fallback
# 12  ok_geopandas_fallback
# 13  ok_geopandas_fallback
# 14  ok_geopandas_fallback
#
#                                                                                                                    error
# 0   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 2   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 3   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 4   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 5   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 6   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 7   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 8   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 9   pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 10  pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 11  pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 12  pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 13  pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 14  pyogrio_read_info fallo: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ## `errores_inventario_capas.csv`
# Filas: **5** | Columnas: **11**
#                                                      ruta nombre_archivo  \
# 0  data\raw\hidrologia_atoyac\conjunto_de_datos\a1809.shp      a1809.shp
# 1  data\raw\hidrologia_atoyac\conjunto_de_datos\i1809.shp      i1809.shp
# 2  data\raw\hidrologia_atoyac\conjunto_de_datos\m1809.shp      m1809.shp
# 3  data\raw\hidrologia_atoyac\conjunto_de_datos\n1809.shp      n1809.shp
# 4  data\raw\hidrologia_atoyac\conjunto_de_datos\p1809.shp      p1809.shp
#
#                         carpeta_origen  numero_features  geometria  crs  \
# 0  hidrologia_atoyac\conjunto_de_datos              NaN        NaN  NaN
# 1  hidrologia_atoyac\conjunto_de_datos              NaN        NaN  NaN
# 2  hidrologia_atoyac\conjunto_de_datos              NaN        NaN  NaN
# 3  hidrologia_atoyac\conjunto_de_datos              NaN        NaN  NaN
# 4  hidrologia_atoyac\conjunto_de_datos              NaN        NaN  NaN
#
#    columnas_disponibles  tipos_columnas  bounds_extension_espacial estado  \
# 0                   NaN             NaN                        NaN  error
# 1                   NaN             NaN                        NaN  error
# 2                   NaN             NaN                        NaN  error
# 3                   NaN             NaN                        NaN  error
# 4                   NaN             NaN                        NaN  error
#
#                                                                                                 error
# 0         UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfa in position 10: invalid start byte
# 1  UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf3 in position 17: invalid continuation byte
# 2   UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 3: invalid continuation byte
# 3   UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 2: invalid continuation byte
# 4   UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 2: invalid continuation byte

# %% [markdown]
# ## 6. Outputs cartográficos

# %%
map_files = sorted(MAPS.glob('*.png'))
fig_files = sorted(FIGURES.glob('*.png'))
html_files = sorted(INTERACTIVE.glob('*.html'))

display(Markdown('### Mapas PNG'))
display(pd.DataFrame({'archivo': [p.name for p in map_files], 'ruta': [str(p.relative_to(ROOT)) for p in map_files], 'kb': [round(p.stat().st_size/1024, 1) for p in map_files]}))

display(Markdown('### Figuras'))
display(pd.DataFrame({'archivo': [p.name for p in fig_files], 'ruta': [str(p.relative_to(ROOT)) for p in fig_files], 'kb': [round(p.stat().st_size/1024, 1) for p in fig_files]}))

display(Markdown('### Mapas interactivos HTML'))
display(pd.DataFrame({'archivo': [p.name for p in html_files], 'ruta': [str(p.relative_to(ROOT)) for p in html_files], 'kb': [round(p.stat().st_size/1024, 1) for p in html_files]}))
# Out:
# ### Mapas PNG
#                                         archivo  \
# 0                   01_contexto_territorial.png
# 1                02_denue_textil_categorias.png
# 2              03_buffers_hidrografia_denue.png
# 3          04_concentracion_textil_por_ageb.png
# 4            05_cauces_rio_red_hidrografica.png
# 5          06_rh18ad_hidrografia_especifica.png
# 6           07_hidrologia_completa_por_tipo.png
# 7        08_hidrologia_completa_por_area_rh.png
# 8                10_huejotzingo_denue_total.png
# 9                 10_san_martin_denue_total.png
# 10              10_xalmimilulco_denue_total.png
# 11   11_huejotzingo_denue_textil_categorias.png
# 12    11_san_martin_denue_textil_categorias.png
# 13  11_xalmimilulco_denue_textil_categorias.png
# 14      12_huejotzingo_heatmap_denue_textil.png
# 15       12_san_martin_heatmap_denue_textil.png
# 16     12_xalmimilulco_heatmap_denue_textil.png
# 17      13_huejotzingo_rangos_distancia_rio.png
# 18       13_san_martin_rangos_distancia_rio.png
# 19     13_xalmimilulco_rangos_distancia_rio.png
#
#                                                         ruta      kb
# 0                   outputs\maps\01_contexto_territorial.png  2650.8
# 1                outputs\maps\02_denue_textil_categorias.png  2665.3
# 2              outputs\maps\03_buffers_hidrografia_denue.png   360.8
# 3          outputs\maps\04_concentracion_textil_por_ageb.png   331.9
# 4            outputs\maps\05_cauces_rio_red_hidrografica.png   870.2
# 5          outputs\maps\06_rh18ad_hidrografia_especifica.png   819.6
# 6           outputs\maps\07_hidrologia_completa_por_tipo.png  1264.4
# 7        outputs\maps\08_hidrologia_completa_por_area_rh.png  1015.4
# 8                outputs\maps\10_huejotzingo_denue_total.png   914.3
# 9                 outputs\maps\10_san_martin_denue_total.png  1279.0
# 10              outputs\maps\10_xalmimilulco_denue_total.png   668.1
# 11   outputs\maps\11_huejotzingo_denue_textil_categorias.png   532.1
# 12    outputs\maps\11_san_martin_denue_textil_categorias.png   656.6
# 13  outputs\maps\11_xalmimilulco_denue_textil_categorias.png   407.7
# 14      outputs\maps\12_huejotzingo_heatmap_denue_textil.png   427.2
# 15       outputs\maps\12_san_martin_heatmap_denue_textil.png   495.5
# 16     outputs\maps\12_xalmimilulco_heatmap_denue_textil.png   312.9
# 17      outputs\maps\13_huejotzingo_rangos_distancia_rio.png   550.7
# 18       outputs\maps\13_san_martin_rangos_distancia_rio.png   673.3
# 19     outputs\maps\13_xalmimilulco_rangos_distancia_rio.png   425.4
# ### Figuras
#                           archivo  \
# 0  saic_indicadores_municipio.png
#
#                                              ruta     kb
# 0  outputs\figures\saic_indicadores_municipio.png  148.3
# ### Mapas interactivos HTML
#                                                  archivo  \
# 0               denue_textil_productivo_interactivo.html
# 1   huejotzingo_denue_textil_productivo_interactivo.html
# 2    san_martin_denue_textil_productivo_interactivo.html
# 3  xalmimilulco_denue_textil_productivo_interactivo.html
#
#                                                                              ruta  \
# 0               outputs\maps_interactive\denue_textil_productivo_interactivo.html
# 1   outputs\maps_interactive\huejotzingo_denue_textil_productivo_interactivo.html
# 2    outputs\maps_interactive\san_martin_denue_textil_productivo_interactivo.html
# 3  outputs\maps_interactive\xalmimilulco_denue_textil_productivo_interactivo.html
#
#        kb
# 0  1538.5
# 1   401.3
# 2   471.3
# 3   218.0

# %%
for name in ['02_denue_textil_categorias.png','03_buffers_hidrografia_denue.png','07_hidrologia_completa_por_tipo.png','08_hidrologia_completa_por_area_rh.png']:
    path = MAPS / name
    if path.exists():
        display(Markdown(f'### {name}'))
        display(Image(filename=str(path), width=850))
# Out:
# ### 02_denue_textil_categorias.png
# ### 03_buffers_hidrografia_denue.png
# ### 07_hidrologia_completa_por_tipo.png
# ### 08_hidrologia_completa_por_area_rh.png

# %% [markdown]
# ## 7. Enlaces rápidos a mapas interactivos
#
# Abre los HTML desde el explorador de archivos o desde Jupyter para consultar cada punto con popup.

# %%
links = []
for p in sorted(INTERACTIVE.glob('*.html')):
    rel = p.relative_to(ROOT).as_posix()
    links.append(f'- [{p.name}](../{rel})')
display(Markdown('\n'.join(links) if links else 'No hay mapas interactivos.'))
# Out:
# - [denue_textil_productivo_interactivo.html](../outputs/maps_interactive/denue_textil_productivo_interactivo.html)
# - [huejotzingo_denue_textil_productivo_interactivo.html](../outputs/maps_interactive/huejotzingo_denue_textil_productivo_interactivo.html)
# - [san_martin_denue_textil_productivo_interactivo.html](../outputs/maps_interactive/san_martin_denue_textil_productivo_interactivo.html)
# - [xalmimilulco_denue_textil_productivo_interactivo.html](../outputs/maps_interactive/xalmimilulco_denue_textil_productivo_interactivo.html)
